# %% [markdown]
# # JOBSHEET 01 - DASAR BAHASA PEMROGRAMAN PYTHON
# ## Nama: Ahmad Fajril Falah
# ## NIM: 4.33.25.1.01
# ## Dosen Penggampu : PRAYITNO , S.ST., M.T., Ph.D
#
#
# Praktikum Pemrograman Berorientasi Objek

# %% [markdown]
# ## Praktikum 01 - Tipe Data Dasar

# %%
print("=== Praktikum 01- Tipe Data Dasar ===\n")
# 1. Number (int, float, complex)
print("=== Tipe Data Number ===")
# Integer (int)
# print("Tipe data integer (int) digunakan untuk menyimpan bilangan bulat.")
angka_int = 10
print("angka_int =", angka_int, "->", type(angka_int))

# Float
# print("\nTipe data float digunakan untuk menyimpan bilangan desimal.")
angka_float = 3.14
print("angka_float =", angka_float, "->", type(angka_float))

# Complex
# print("\nTipe data complex digunakan untuk menyimpan bilangan kompleks.")
angka_complex = 2 + 3j
print("angka_complex =", angka_complex, "->", type(angka_complex))

# 2. Boolean
print("\n=== Tipe Data Boolean ===")
# print("Tipe data boolean digunakan untuk menyimpan nilai True atau False.")
is_active = True
print("is_active =", is_active, "->", type(is_active))

# 3. String
print("\n=== Tipe Data String ===")
# print("Tipe data string digunakan untuk menyimpan teks.")
teks = "Hello, Python!"
print("teks =", teks, "->", type(teks))

# 4. List
print("\n=== Tipe Data List ===")
# print("Tipe data list digunakan untuk menyimpan kumpulan data yang terurut dan dapat diubah(Mutable).")
daftar_angka = [1, 2, 3, 4, 5]
print("daftar_angka =", daftar_angka, "->", type(daftar_angka))

# 5. Tuple
print("\n=== Tipe Data Tuple ===")
# print("Tipe data tuple digunakan untuk menyimpan kumpulan data yang terurut tetapi tidak dapat diubah(Immutable).")
koordinat = (10, 20)
print("koordinat =", koordinat, "->", type(koordinat))

# 6. Dictionary
print("\n=== Tipe Data Dictionary ===")
# print("Tipe data dictionary digunakan untuk menyimpan data dalam pasangan key-value.")
data_mahasiswa = {
    "nama": "Andi",
    "nim": "A11.2022.12345",
    "jurusan": "Teknik Informatika"
}
print("data_mahasiswa =", data_mahasiswa, "->", type(data_mahasiswa))

# 7. Set
print("\n=== Tipe Data Set ===")
# print("Tipe data set digunakan untuk menyimpan kumpulan data yang tidak terurut dan unik(tiap elemen hanya muncul 1x).")
himpunan_angka = {1, 2, 3, 2, 1}
print("himpunan_angka =", himpunan_angka, "->", type(himpunan_angka))

# 8. Contoh penggunaan konversi tipe data
print("\n=== Contoh Konversi Tipe Data ===")
# print("Konversi tipe data digunakan untuk mengubah tipe data suatu nilai ke tipe data lain.")
nilai_str = "100"
print("nilai_str =", nilai_str, "->", type(nilai_str))
nilai_int = int(nilai_str)  # konversi string ke integer
print("nilai_int =", nilai_int, "->", type(nilai_int))
# Out:
# === Praktikum 01- Tipe Data Dasar ===
#
# === Tipe Data Number ===
# angka_int = 10 -> <class 'int'>
# angka_float = 3.14 -> <class 'float'>
# angka_complex = (2+3j) -> <class 'complex'>
#
# === Tipe Data Boolean ===
# is_active = True -> <class 'bool'>
#
# === Tipe Data String ===
# teks = Hello, Python! -> <class 'str'>
#
# === Tipe Data List ===
# daftar_angka = [1, 2, 3, 4, 5] -> <class 'list'>
#
# === Tipe Data Tuple ===
# koordinat = (10, 20) -> <class 'tuple'>
#
# === Tipe Data Dictionary ===
# data_mahasiswa = {'nama': 'Andi', 'nim': 'A11.2022.12345', 'jurusan': 'Teknik Informatika'} -> <class 'dict'>
#
# === Tipe Data Set ===
# himpunan_angka = {1, 2, 3} -> <class 'set'>
#
# === Contoh Konversi Tipe Data ===
# nilai_str = 100 -> <class 'str'>
# nilai_int = 100 -> <class 'int'>

# %% [markdown]
# ## Praktikum 02 - Variabel dan Operasi

# %%
# 1. Pendeklarasian Variabel
print("\n=== Pendeklarasian Variabel ===")
nama = "Budi"
umur = 20
tinggi = 170.5
is_student = True

print("Nama =", nama)
print("Umur =", umur)
print("Tinggi =", tinggi, "cm")
print("Mahasiswa =", is_student)

# Python tidak memerlukan deklarasi tipe data secara eksplisit.
# Tipe data variabel akan menyesuaikan nilai yang diberikan.

# 2. Operasi Aritmetika
a = 10
b = 3

penjumlahan = a + b      # Tambah
pengurangan = a - b      # Kurang
perkalian = a * b        # Kali
pembagian = a / b        # Bagi (hasil float)
pembagian_bulat = a // b # Bagi (bulat)
modulus = a % b          # Sisa bagi
pangkat = a ** b         # Pemangkatan

print("\n=== OPERASI ARITMETIKA ===")
print("a =", a, ", b =", b)
print("Penjumlahan =", penjumlahan)
print("Pengurangan =", pengurangan)
print("Perkalian =", perkalian)
print("Pembagian =", pembagian)
print("Pembagian Bulat =", pembagian_bulat)
print("Modulus =", modulus)
print("Pangkat =", pangkat)

# 3. Operasi Perbandingan
# Menghasilkan nilai Boolean (True/False)
lebih_besar = a > b
kurang_dari = a < b
sama_dengan = a == b
tidak_sama = a != b
lebih_besar_sama = a >= b
kurang_sama = a <= b

print("\n=== OPERASI PERBANDINGAN ===")
print("a > b =", lebih_besar)
print("a < b =", kurang_dari)
print("a == b =", sama_dengan)
print("a != b =", tidak_sama)
print("a >= b =", lebih_besar_sama)
print("a <= b =", kurang_sama)

# 4. Operasi Logika
# and, or, not

x = True
y = False

logika_and = x and y
logika_or = x or y
logika_not_x = not x

print("\n=== OPERASI LOGIKA ===")
print("x =", x, ", y =", y)
print("x and y =", logika_and)
print("x or y =", logika_or)
print("not x =", logika_not_x)

# 5. Contoh penggunaan di dalam percabangan
print("\n=== Contoh Penggunaan di Dalam Percabangan ===")
if a > b and b > 0:
    print("\nKondisi terpenuhi: a lebih besar dari b, dan b masih positif.")
else:
    print("\nKondisi tidak terpenuhi atau b <= 0.")
# Out:
# === Pendeklarasian Variabel ===
# Nama = Budi
# Umur = 20
# Tinggi = 170.5 cm
# Mahasiswa = True
#
# === OPERASI ARITMETIKA ===
# a = 10 , b = 3
# Penjumlahan = 13
# Pengurangan = 7
# Perkalian = 30
# Pembagian = 3.3333333333333335
# Pembagian Bulat = 3
# Modulus = 1
# Pangkat = 1000
#
# === OPERASI PERBANDINGAN ===
# a > b = True
# a < b = False
# a == b = False
# a != b = True
# a >= b = True
# a <= b = False
#
# === OPERASI LOGIKA ===
# x = True , y = False
# x and y = False
# x or y = True
# not x = False
#
# === Contoh Penggunaan di Dalam Percabangan ===
#
# Kondisi terpenuhi: a lebih besar dari b, dan b masih positif.

# %% [markdown]
# ## Praktikum 03 - Percabangan

# %%
# 1. IF Sederhana
print("\n=== IF Sederhana ===")
# Program hanya mengeksekusi blok jika kondisinya True

nilai = 85
print("Contoh IF Sederhana:")
if nilai > 80:
    print("Selamat! Anda lulus dengan nilai tinggi.\n")


# 2. IF-ELSE
print("\n=== IF-ELSE ===")
# Jika kondisi True, eksekusi blok if; jika False, eksekusi blok else

umur = 17
print("Contoh IF-ELSE:")
if umur >= 18:
    print("Anda sudah cukup umur untuk mendapatkan SIM.")
else:
    print("Anda belum cukup umur untuk mendapatkan SIM.\n")


# 3. IF-ELIF-ELSE
print("\n=== IF-ELIF-ELSE ===")
# Menangani banyak kondisi secara berurutan.
# Jika ada kondisi yang terpenuhi, blok yang bersangkutan dieksekusi,
# lalu program melewati blok kondisi setelahnya.

hari = "Rabu"
print("Contoh IF-ELIF-ELSE:")
if hari == "Senin":
    print("Hari Senin - Saatnya kembali bekerja!")
elif hari == "Selasa":
    print("Hari Selasa - Jadwal rapat mingguan.")
elif hari == "Rabu":
    print("Hari Rabu - Ada diskon di beberapa toko.")
else:
    print("Hari lainnya - Atur jadwalmu dengan baik.\n")


# 4. IF Bersarang (Nested IF)
print("\n=== IF Bersarang (Nested IF) ===")
# Kondisi di dalam kondisi, biasa digunakan jika kita perlu
# memeriksa sub-kondisi setelah kondisi pertama terpenuhi.

suhu = 35
print("Contoh IF Bersarang (Nested IF):")
if suhu > 30:
    print("Cuaca cukup panas.")
    if suhu > 40:
        print("Bahkan sangat terik! Disarankan banyak minum air.")
    else:
        print("Masih relatif normal, tapi tetap jaga kesehatan.")
else:
    print("Cuaca sepertinya cukup sejuk.\n")


# 5. Menggabungkan Percabangan dengan Operasi Logika
print("\n=== Menggabungkan Percabangan dengan Operasi Logika ===")
# Memeriksa beberapa kondisi sekaligus dengan and, or, not

nilai_teori = 75
nilai_praktik = 80
print("Contoh IF dengan Operasi Logika AND/OR:")
if nilai_teori >= 70 and nilai_praktik >= 70:
    print("Anda lulus karena nilai teori dan praktik memadai.")
elif nilai_teori < 70 and nilai_praktik < 70:
    print("Anda perlu meningkatkan nilai teori dan praktik.")
elif nilai_teori < 70:
    print("Anda perlu meningkatkan nilai teori.")
else:
    print("Anda perlu meningkatkan nilai praktik.\n")


# 6. Penggunaan If Ternary (atau Conditional Expression)
print("\n=== IF Ternary (Conditional Expression) ===")
# Bentuk ringkas: <hasil_if_true> if <kondisi> else <hasil_if_false>

angka = -5
print("Contoh If Ternary (Conditional Expression):")
status = "Positif" if angka > 0 else "Negatif atau Nol"
print("Angka =", angka, "=>", status)
# Out:
# === IF Sederhana ===
# Contoh IF Sederhana:
# Selamat! Anda lulus dengan nilai tinggi.
#
#
# === IF-ELSE ===
# Contoh IF-ELSE:
# Anda belum cukup umur untuk mendapatkan SIM.
#
#
# === IF-ELIF-ELSE ===
# Contoh IF-ELIF-ELSE:
# Hari Rabu - Ada diskon di beberapa toko.
#
# === IF Bersarang (Nested IF) ===
# Contoh IF Bersarang (Nested IF):
# Cuaca cukup panas.
# Masih relatif normal, tapi tetap jaga kesehatan.
#
# === Menggabungkan Percabangan dengan Operasi Logika ===
# Contoh IF dengan Operasi Logika AND/OR:
# Anda lulus karena nilai teori dan praktik memadai.
#
# === IF Ternary (Conditional Expression) ===
# Contoh If Ternary (Conditional Expression):
# Angka = -5 => Negatif atau Nol

# %% [markdown]
# ## Praktikum 04 - Perulangan

# %%
# -*- coding: utf-8 -*-

# 1. FOR Loop dengan range()
print("1) FOR loop dengan range()")
for i in range(5):
    print("Perulangan ke-", i)
# range(5) menghasilkan nilai 0, 1, 2, 3, dan 4
# Sehingga perulangan akan berjalan sebanyak 5 kali

print()  # pemisah output

# 2. FOR Loop untuk mengiterasi List
print("2) FOR loop mengiterasi list")
buah = ["apel", "mangga", "jeruk", "pisang"]
for item in buah:
    print("Buah:", item)
# Loop akan mengeksekusi setiap elemen dalam list "buah"

print()

# 3. WHILE Loop
print("3) WHILE loop sederhana")
count = 0
while count < 5:
    print("count =", count)
    count += 1  # increment
# Perulangan while terus dijalankan selama kondisi (count < 5) bernilai True

print()

# 4. BREAK pada Loop
print("4) BREAK di dalam loop")
for i in range(10):
    if i == 3:
        print("Loop dihentikan pada i =", i)
        break  # mengakhiri loop saat i = 3
    print("i =", i)
# Keyword break langsung menghentikan keseluruhan perulangan

print()

# 5. CONTINUE pada Loop
print("5) CONTINUE di dalam loop")
for i in range(5):
    if i == 2:
        print("Lewati i =", i, "dengan continue")
        continue  # melewati iterasi saat ini dan lanjut ke iterasi berikutnya
    print("i =", i)
# Saat i = 2, baris print("i =", i) tidak akan dieksekusi

print()

# 6. NESTED Loop (Loop Bersarang)
print("6) NESTED loop")
for i in range(3):            # Loop luar (outer loop)
    for j in range(2):        # Loop dalam (inner loop)
        print(f"i={i}, j={j}")
# Pada setiap iterasi i, loop j akan berjalan dari 0 sampai 1

print()

# 7. Memanfaatkan ELSE pada Loop
print("7) ELSE pada loop for/while")
# Python memiliki fitur unik: blok else pada loop
# Blok else akan dieksekusi jika loop selesai tanpa di-break.

for x in range(3):
    print("x =", x)
else:
    print("Loop for telah selesai tanpa break.\n")

y = 0
while y < 3:
    print("y =", y)
    y += 1
else:
    print("Loop while telah selesai tanpa break.\n")


# 8. PASS sebagai placeholder
print("8) PASS (placeholder)")
for i in range(3):
    if i == 1:
        pass  # pass tidak melakukan apa-apa, digunakan sebagai placeholder
    print("i =", i)
# Out:
# 1) FOR loop dengan range()
# Perulangan ke- 0
# Perulangan ke- 1
# Perulangan ke- 2
# Perulangan ke- 3
# Perulangan ke- 4
#
# 2) FOR loop mengiterasi list
# Buah: apel
# Buah: mangga
# Buah: jeruk
# Buah: pisang
#
# 3) WHILE loop sederhana
# count = 0
# count = 1
# count = 2
# count = 3
# count = 4
#
# 4) BREAK di dalam loop
# i = 0
# i = 1
# i = 2
# Loop dihentikan pada i = 3
#
# 5) CONTINUE di dalam loop
# i = 0
# i = 1
# Lewati i = 2 dengan continue
# i = 3
# i = 4
#
# 6) NESTED loop
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1
#
# 7) ELSE pada loop for/while
# x = 0
# x = 1
# x = 2
# Loop for telah selesai tanpa break.
#
# y = 0
# y = 1
# y = 2
# Loop while telah selesai tanpa break.
#
# 8) PASS (placeholder)
# i = 0
# i = 1
# i = 2

# %% [markdown]
# ## === Penugasan JOBSHEET 1 ===

# %% [markdown]
# ## Program 1 - BMI (Body Mass Index)

# %%
print("Ahmad Fajril Falah")
print("=== Body Mass Index (BMI) Calculator ===")
print("Masukkan berat (kg) dan tinggi (cm) untuk menghitung BMI.")
berat = float(input("Masukkan berat (kg): "))
tinggi = float(input("Masukkan tinggi (cm): "))

tinggi_m = tinggi / 100 # konversi cm ke meter
bmi = berat / (tinggi_m ** 2)  # perhitungan BMI berat dibagi tinggi kuadrat

if bmi < 18.5: # jika BMI kurang dari 18.5
    kategori = "Underweight" # maka kategorinya adalah Underweight
elif bmi <= 24.9: # jika BMI lebih dari <= 24.9
    kategori = "Normal" # maka kategori adalah Normal
elif bmi <= 29.9: # jika BMI lebih dari <= 29.9
    kategori = "Overweight" # maka kategori adalah Overweight
else: # jika BMI lebih dari 30
    kategori = "Obesitas" # maka kategorinya adalah Obesitas

print("BMI:", bmi)
print("Kategori:", kategori)
# Out:
# Ahmad Fajril Falah
# === Body Mass Index (BMI) Calculator ===
# Masukkan berat (kg) dan tinggi (cm) untuk menghitung BMI.
# BMI: 21.71806608974573
# Kategori: Normal

# %% [markdown]
# ## Program 2 - Cek Bilangan

# %%
print("Ahmad Fajril Falah")
print("=== Cek Bilangan Genap/Ganjil dan Prima ===")
angka = int(input("Masukkan angka: "))

# Bil Genap / Ganjil
if angka % 2 == 0: # jika angka habis dibagi 2 (sisa bagi 0), maka angka adalah genap
    print("Bilangan Genap")
else:
    print("Bilangan Ganjil")

# Cek apaka Bil Prima?
if angka > 1: # bilangan yang lebih besar dari 1 dan hanya memiliki 2 faktor yaitu 1 dan dirinya sendiri
    for i in range(2, angka): # loop dari 2 sampai angka-1 untuk memeriksa faktor pembagi
        if angka % i == 0: # jika angka habis dibagi i, maka angka bukan prima
            print("Bukan Bilangan Prima")
            break # keluar dari loop jika sudah ketemu faktor pembagi
    else:
        print("Bilangan Prima") # jika loop selesai tanpa break, maka angka adalah prima
else:
    print("Bukan Bilangan Prima") # bilangan 0, 1, dan bilangan negatif bukan bilangan prima
# Out:
# Ahmad Fajril Falah
# === Cek Bilangan Genap/Ganjil dan Prima ===
# Bilangan Ganjil
# Bilangan Prima
